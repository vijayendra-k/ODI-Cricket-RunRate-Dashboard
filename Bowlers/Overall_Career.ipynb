# %%
import pandas as pd

# %%
dataset=pd.read_csv("C:/Users/Vijay/OneDrive/Documents/Others/odi_bbb_2005_2024.csv")
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_14672\990751168.py:1: DtypeWarning: Columns (40,51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset=pd.read_csv("C:/Users/Vijay/OneDrive/Documents/Others/odi_bbb_2005_2024.csv")

# %%
dataset
# Out:
#          p_match  inns                 bat    p_bat   team_bat        bowl  \
# 0         226390     1       Upul Tharanga    50747  Sri Lanka  Kyle Mills
# 1         226390     1       Upul Tharanga    50747  Sri Lanka  Kyle Mills
# 2         226390     1       Upul Tharanga    50747  Sri Lanka  Kyle Mills
# 3         226390     1       Upul Tharanga    50747  Sri Lanka  Kyle Mills
# 4         226390     1       Upul Tharanga    50747  Sri Lanka  Kyle Mills
# ...          ...   ...                 ...      ...        ...         ...
# 1322268  1412540     2     Janith Liyanage   681681  Sri Lanka   Ryan Burl
# 1322269  1412540     2     Janith Liyanage   681681  Sri Lanka   Ryan Burl
# 1322270  1412540     2  Maheesh Theekshana  1138316  Sri Lanka   Ryan Burl
# 1322271  1412540     2  Maheesh Theekshana  1138316  Sri Lanka   Ryan Burl
# 1322272  1412540     2  Maheesh Theekshana  1138316  Sri Lanka   Ryan Burl
#
# ...

# %%
balls=dataset.groupby(by='bowl')['ballfaced'].sum().reset_index()
totalballs=pd.DataFrame(balls)

# %%
totalballs.to_csv('totalballs.csv')
